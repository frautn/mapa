# %% [markdown]
# 13_diffbot_playground.ipynb
# --------------
# Testing how diffbot API works.
#
#
# Make sure to set your Diffbot API key in a .env file as follows:
#     DIFFBOT_API_KEY=your_diffbot_api_key

# %%
import requests
import json

from dotenv import load_dotenv
import os
load_dotenv()  # Automatically finds .env file
api_key = os.getenv('DIFFBOT_API_KEY')

# %% [markdown]
# ## Consultar créditos y otros datos de cuenta

# %%
url = f"https://api.diffbot.com/v4/account?token={api_key}"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)

# %%
response_json = response.json()
response_json['usage']

# %%
total_credits = 0
for u in response_json['usage']:
    total_credits += u['credits']
print(f"Total credits: {total_credits}")

# %% [markdown]
# ## Extraer artículos

# %%
from pathlib import Path
import pandas as pd

base_dir = Path.cwd()
csv_path = base_dir / ".." / "data" / "Monitoreo noticias – Mapa de la Policía_with_ID.csv"


df = pd.read_csv(csv_path)
print(f"Number of rows in DataFrame: {len(df)}")
# Out:
# Number of rows in DataFrame: 2340

# %%
url = f"https://api.diffbot.com/v3/article?token={api_key}"

headers = {}

link = 'https://news.google....?oc=5'
# link = df.iloc[0]['Link']

params = {
  "url": link
}

response = requests.request("GET", url, params=params, headers=headers)

response_json = response.json()
response_json
# Out:
# {'request': {'pageUrl': 'https://news.google....?oc=5',
#   'api': 'article',
#   'version': 3},
#  'objects': [{'date': 'Sat, 27 Dec 2025 19:29:00 GMT',
#    'sentiment': -0.938,
#    'images': [{'naturalHeight': 450,
#      'width': 720,
#      'url': 'https://cdn.eldestapeweb.com/eldestape/122025/1766869747271.webp?cw=800&ch=450&extw=jpg',
#      'naturalWidth': 800,
#      'primary': True,
#      'height': 405}],
#    'author': 'El Destape',
#    'shareLinks': False,
#    'estimatedDate': 'Sat, 27 Dec 2025 19:29:00 GMT',
#    'icon': 'https://www.eldestapeweb.com/img/favicons/apple-icon-180x180.png',
#    'diffbotUri': 'article|3|-1760250293',
#    'siteName': 'El Destape',
#    'type': 'article',
#    'title': 'Confirman que el vecino de Lugano fallecido recibió "un disparo letal"',
#    'tags': [{'score': 0.6577073931694031,
#      'sentiment': 0,
#      'count': 1,
#      'label': 'Correpi Córdoba',
#      'uri': 'https://diffbot.com/entity/E2g13YEBxOWSchbaOVr8k3A',
#      'rdfTypes': ['http://dbpedia.org/ontology/Organisation']}],
#    'humanLanguage': 'es',
#    'pageUrl': 'https://news.google....?oc=5',
#    'html': '<figure><img alt="Confirman que el vecino de Lugano fallecido recibió &quot;un disparo letal&quot;" data-amp-auto-lightbox-disable="" src="https://cdn.eldestapeweb.com/eldestape/122025/1766869747271.webp?cw=800&ch=450&extw=jpg"></img></figure>\n<p>La <strong>Coordinadora contra la</strong> <strong>Represi&oacute;n Policial e Institucional </strong>(CORREPI) confirm&oacute; que <strong><a href="
matar a corta distancia. Por eso los protocolos de uso de armas largas proh&iacute;ben terminantemente disparar directamente al cuerpo con cualquier tipo de cartucher&iacute;a&quot;</strong>, sostuvo la organizaci&oacute;n.</p>\n<h2>El nombre de los implicados</h2>\n<p>Correpi tambi&eacute;n dio a conocer <strong>detalles de los oficiales que participaron del operativo </strong>del jueves pasado, que qued&oacute; registrado en un video en el que se puede ver a Gonz&aacute;lez enfrentando al menos cinco efectivos de la polic&iacute;a sin portar armas y con el torso desnudo. ...
#    'categories': [{'score': 0.527, 'name': 'Law', 'id': 'iabv2-383'},
#     {'score': 0.957, 'name': 'Crime', 'id': 'iabv2-380'},
#     {'score': 0.957, 'name': 'News and Politics', 'id': 'iabv2-379'}],
#    'text': 'La Coordinadora contra la Represión Policial e Institucional (CORREPI) confirmó que Gabriel González, el vecino de la villa 20 de Lugano fallecido durante los festejos de Navidad, recibió "un impacto directo al cuerpo de alguna de las armas largas" utilizadas por efectivos de la Policía de la Ciudad. También revelaron el nombre de los agentes involucrados en el operativo y sería el oficial primero Daniel Miño, perteneciente a la Comisaría 8A, quien habría efectuado el disparo de escopeta mortal.\nPoco después, el Ministerio de Seguridad de la Ciudad emitió un comunicado en el que informó que "se inició una investigación disciplinaria que derivó en la decisión de pasar a disponibilidad a un oficial primero de la comisaría 8 A, a fin de facilitar al Juzgado interventor la investigación de los hechos ocurridos en la Villa 20 de Lugano". No dio el nombre del policía desplazado.\nLa denuncia de Correpi\n"El anticipo preliminar de la autopsia, informado hoy a la familia de Juan Gabriel González, es conciso y claro: Lesiones por proyectil de munición múltiple en tórax y abdomen. Hemorragia interna y externa", indicó la organización en un comunicado. Este informe previo del Cuerpo Médico Forense, continuó, es "dirimente" sobre los motivos del fallecimiento del vecino de 45 años de Lugano. "Recibió un impacto directo al cuerpo de alguna de las armas largas utilizadas por los policías de la Ciudad, tal como se ve en los videos ya conocidos", se agregó en el texto.\nPese a que aún se desconoce si los agentes utilizaron balas de goma o de plomo durante el operativo, Correpi subrayó que un balazo "a corta distancia", como lo muestran las imágenes filmadas por otros vecinos, y "directo a zonas vitales como tórax y abdomen" es "un disparo letal" para cualquiera que lo reciba.\n"Hasta un cartucho de estruendo (sin munición) puede herir o matar a corta distancia. Por eso los protocolos de uso de armas largas prohíben terminantemente disparar directamente al cuerpo con cualquier tipo de cartuchería", sostuvo la organización.\nEl nombre de los implicados\nCorrepi también dio a conocer detalles de los oficiales que participaron del operativo del jueves pasado, que quedó registrado en un video en el que se puede ver a González enfrentando al menos cinco efectivos de la policía sin portar armas y con el torso desnudo.\n"Serían el oficial primero Daniel Miño, L.P. 15.711 (Comisaría 8A), la oficial Vanesa Valentini, L.P. 28.675, el oficial primero Joel Riquelme, L.P. 8.998 y la oficial Evelyn Goncebat, L.P 29.359, éstos de la División Unidad Táctica de Pacificación VI. Según el parte policial, quienes dispararon sus armas largas fueron la oficial Valentini y el oficial 1° Miño, que habrían disparado seis veces cada uno", informó la organización\nEn las imágenes que se hicieron públicas se observa cómo los policías reducen a golpes a González y, posteriormente, uno de ellos efectúa un disparo, tras el cual el joven cae al suelo. "Ampliaremos la información a medida que podamos constatarla. Basta de gatillo fácil, basta de represión", lanzó Correpi.\nQué dijo el gobierno de la Ciudad\nEl sábado, el Ministerio de Seguridad de la Ciudad de Buenos Aires emitió un comunicado en el que mantuvo su versión de que los policías fueron los agredidos, pero reconoció que apartó a un oficial y que la Justicia está investigando la represión. "El 25 de diciembre a las 12:48 horas ingresa un llamado al 911 de una mujer que solicita presencia policial en Chilavert y Araujo, porque personas alcoholizadas estaban tirando botellas contra su domicilio. Luego se recibieron dos llamados más al 911 denunciando una pelea entre vecinos con personas que se arrojaban botellas entre sí", relató el texto del Ministerio.\n"Al lugar arribó personal de la División Unidad Táctica de Pacificación que solicitó el cese de las agresiones y al no acatarse la orden se inició una refriega con las personas que estaban peleando. Los efectivos policiales comenzaron a ser agredidos fí ...
#    'resolvedPageUrl': 'https://www.eldestapeweb.com/sociedad/policia-de-la-ciudad/confirman-que-el-vecino-de-lugano-fallecido-recibio-un-disparo-letal-20251227192952'}]}

# %%
response_json['objects'][0]['text']

# %%
response_json['objects'][0]['title']

# %%
response_json['objects'][0]['siteName']

# %%
response_json['objects'][0]['resolvedPageUrl']

# %%
response_json['objects'][0]['date']

# %%
labels = []
for l in response_json['objects'][0]['tags']:
    labels.append(l['label'])
print(labels)

# %%
categories = []
for c in response_json['objects'][0]['categories']:
    categories.append(c['name'])
print(categories)

# %% [markdown]
# ## Loading response json from csv file

# %%
from pathlib import Path
import json
import pandas as pd

base_dir = Path.cwd()
csv_path = base_dir / ".." / "data" / "Monitoreo noticias with articles.csv"


df = pd.read_csv(csv_path)
print(f"Number of rows in DataFrame: {len(df)}")

# %%
s = df.iloc[0]['diffbot_response']

# %%
obj = json.loads(s)

# %%
obj

# %%
obj['objects'][0]['html']

# %% [markdown]
# Different approach, for testing Django procedure.

# %%
import csv
from datetime import datetime
import json

# %%
csv_path = base_dir / ".." / "data" / "djangoTest - Monitoreo noticias parcial.csv"

with open(csv_path, "rb") as uploaded_file:
    decoded_file = uploaded_file.read().decode("utf-8-sig").splitlines()
reader = csv.DictReader(decoded_file)

# %%
# Walk until the index you want
N = 27
for i, row in enumerate(reader):
    if i == N:
        target_row = row
        break

# %%
target_row['Título']

# %%
(target_row.get('diffbot_response') or '{}')

# %%
obj = json.loads((target_row.get('diffbot_response') or '{}').strip())

# %%
json_obj = (obj.get('objects') or [{}])[0]

# %%
json_obj.get('date')

# %%
target_row.get('Validado')

# %%
json_obj.get('resolvedPageUrl')
